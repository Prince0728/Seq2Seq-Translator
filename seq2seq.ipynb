# %% [markdown]
# ### STEP 1. 引入相關的函數庫

# %%
from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Activation, dot, concatenate, Dropout, BatchNormalization, TimeDistributed
import numpy as np
import os
from IPython.display import Image
# %matplotlib inline

# %% [markdown]
# ### STEP 2. 相關的參數

# %%
batch_size = 64 # 訓練時的批次數量
latent_dim = 256 # 編碼後的潛在空間的維度(dimensions of latent space)
num_samples = 15000 # 用來訓練的樣本數

# %% [markdown]
# ### STEP 3.資料的前處理

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 資料向量化
input_texts = []
target_texts = []
input_characters = set() # 英文字符集
target_characters = set() # 中文字符集
lines = open('/content/drive/MyDrive/02NLP/cmn-tw.txt', mode='r', encoding='utf-8').read().split('\n')

# 逐行的讀取與處理
for line in lines[: min(num_samples, len(lines)-1)]:
    input_text, target_text = line.split('\t')

    # 我們使用“tab”作為“開始序列[SOS]”字符或目標，“\n”作為“結束序列[EOS]”字符。 <-- **重要
    target_text = '\t' + target_text + '\n'

    input_texts.append(input_text)
    target_texts.append(target_text)

    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters)) # 全部輸入的字符集
target_characters = sorted(list(target_characters)) # 全部目標字符集

num_encoder_tokens = len(input_characters) # 所有輸入字符的數量
num_decoder_tokens = len(target_characters) # 所有目標字符的數量

max_encoder_seq_length = max([len(txt) for txt in input_texts]) # 最長的輸入句子長度
max_decoder_seq_length = max([len(txt) for txt in target_texts]) # 最長的目標句子長度

print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)

# 輸入字符的索引字典
input_token_index = dict(
    [(char, i) for i, char in enumerate(input_characters)])

# 目標字符的索引字典
target_token_index = dict(
    [(char, i) for i, char in enumerate(target_characters)])

print(input_token_index)
print(target_token_index)
# Out:
# Number of samples: 15000
# Number of unique input tokens: 73
# Number of unique output tokens: 2435
# Max sequence length for inputs: 40
# Max sequence length for outputs: 25
# {' ': 0, '!': 1, '"': 2, '$': 3, '%': 4, "'": 5, ',': 6, '-': 7, '.': 8, '0': 9, '1': 10, '2': 11, '3': 12, '4': 13, '5': 14, '6': 15, '7': 16, '8': 17, '9': 18, ':': 19, '?': 20, 'A': 21, 'B': 22, 'C': 23, 'D': 24, 'E': 25, 'F': 26, 'G': 27, 'H': 28, 'I': 29, 'J': 30, 'K': 31, 'L': 32, 'M': 33, 'N': 34, 'O': 35, 'P': 36, 'Q': 37, 'R': 38, 'S': 39, 'T': 40, 'U': 41, 'V': 42, 'W': 43, 'Y': 44, 'Z': 45, 'a': 46, 'b': 47, 'c': 48, 'd': 49, 'e': 50, 'f': 51, 'g': 52, 'h': 53, 'i': 54, 'j': 55, 'k': 56, 'l': 57, 'm': 58, 'n': 59, 'o': 60, 'p': 61, 'q': 62, 'r': 63, 's': 64, 't': 65, 'u': 66, 'v': 67, 'w': 68, 'x': 69, 'y': 70, 'z': 71, '’': 72}
, '凍': 256, '凝': 257, '凡': 258, '凰': 259, '凳': 260, '出': 261, '函': 262, '刀': 263, '分': 264, '切': 265, '划': 266, '列': 267, '初': 268, '判': 269, '別': 270, '利': 271, '刪': 272, '刮': 273, '到': 274, '制': 275, '刷': 276, '刺': 277, '刻': 278, '則': 279, '前': 280, '剎': 281, '剛': 282, '剩': 283, '剪': 284, '副': 285, '創': 286, '劃': 287, '劇': 288, '劈': 289, '力': 290, '功': 291, '加': 292, '助': 293, '努': 294, '劫': 295, '勁': 296, '勇': 297, '勉': 298, '動': 299, '務': 300, '勝': 301, '勞': 302, '勢': 303, '勤': 304, '勵': 305, '勸': 306, '勺': 307, '包': 308, '匆': 309, '匈': 310, '化': 311, '北': 312, '匙': 313, '匠': 314, '匯': 315, '匱': 316, '匹': 317, '區': 318, '十': 319, '千': 320, '升': 321, '午': 322, '半': 323, '協': 324, '南': 325, '博': 326, '占': 327, '卡': 328, '印': 329, '危': 330, '即': 331, '卵': 332, '卷': 333, '卹': 334, '卻': 335, '厄': 336, '厚': 337, '原': 338, '厭': 339, '厲': 340, '去': 341, '參': 342, '又': 343, '叉': 344, '及': 345, '友': 346, '反': 347, '叔': 348, '取': 349, '受': 350, '叢': 351, '口': 352, '古': 353, '句': 354, '另': 355, '只': 356, '叫': 357, '召': 358, '叮': 359, '可': 360, '台': 361, '史': 362, '右': 363, '司': 364, '吃': 365, '各': 366, '合': 367, '吉': 368, '同': 369, '名': 370, '后': 371, '吐': 372, '向': 373, '君': 374, '吝': 375, '吟': 376, '吠': 377, '否': 378, '吧': 379, '含': 380, '听': 381, '吵': 382, '吸': 383, '吹': 384, '吻': 385, '吼': 386, '呀': 387, '呆': 388, '告': 389, '呢': 390, '周': 391, '味': 392, '呻': 393, '呼': 394, '命': 395, '咄': 396, '咆': 397, '和': 398, '咎': 399, '咒': 400, '咖': 401, '咪': 402, '咬': 403, '咱': 404, '咳': 405, '品': 406, '哇': 407, '哈': 408, '員': 409, '哥': 41 ...

# %%
# 包含英文句子的2維形狀數組（num_pairs，max_english_sentence_length）
encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length), dtype='float32')

# 包含中文句子的2維形狀數組（num_pairs，max_chinese_sentence_length）
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length), dtype='float32')

# decoder_target_data與decoder_input_data偏移了一個時間步長。one hot?
# decoder_target_data [:, t，：]將與decoder_input_data [：，t + 1]- one hot 相同
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype='float32')

# 把資料轉換成要用來訓練用的張量資料結構 <-- 重要 label encoding
for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t] = input_token_index[char]

    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t] = target_token_index[char]
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.

# %% [markdown]
# ### STEP 4.構建網絡架構

# %%
# ===== 編碼 (encoder) ====

# 定義輸入的序列
# 注意：因為輸入序列長度(timesteps)可變的情況，使用input_shape =（None,）
encoder_inputs = Input(shape=(None,), name='encoder_input')
enc_embed = Embedding(num_encoder_tokens+1, 128, input_length=None, name='enc_embedding')
encoder = LSTM(latent_dim, return_sequences=True, return_state=True, name='encoder_lstm') # ****
# 需要取得LSTM的內部state, 因此設定"return_state=True"
# attention 需要取得 LSTMreturn的sequence, 因此設定"return_sequence=True"
encoder_outputs, state_h, state_c = encoder(enc_embed(encoder_inputs))
# 我們拋棄掉`encoder_outputs`因為我們只需要LSTM cell的內部state參數
encoder_states = [state_h, state_c]
encoder_outputs_3 = [encoder_outputs, state_h, state_c]

# ==== 解碼 (decoder) ====
# 設定解碼器(decoder)
# 注意：因為輸出序列的長度(timesteps)是變動的，使用input_shape =（None,）
decoder_inputs = Input(shape=(None,), name='decoder_input')
dec_embed = Embedding(num_decoder_tokens+1, 128, input_length=None, name='dec_embedding')
# 我們設定我們的解碼器回傳整個輸出的序列同時也回傳內部的states參數
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True, name='decoder_lstm')

# 在訓練時我們不會使用這些回傳的states, 但是在預測時我們會用到這些states參數
# **解碼器的初始狀態是使用編碼器的最後的狀態(states)**
decoder_outputs, _, _ = decoder_lstm(dec_embed(decoder_inputs), initial_state=encoder_states) #我們使用`encoder_states`來做為初始值(initial state)
attention = dot([decoder_outputs, encoder_outputs], axes=[2, 2])
attention = Activation('softmax')(attention)
context = dot([attention, encoder_outputs], axes=[2,1])
decoder_outputs = concatenate([context, decoder_outputs])
concat_dense = Dense(num_decoder_tokens, activation='tanh', name='concat_output')
decoder_outputs = concat_dense(decoder_outputs)
second_dense = Dense(num_decoder_tokens, activation='tanh', name='second_output')
decoder_outputs = second_dense(decoder_outputs)

# 接密集層(dense)來進行softmax運算每一個字符可能的機率
decoder_dense = Dense(num_decoder_tokens, activation='softmax', name='decoder_output')
decoder_outputs = decoder_dense(decoder_outputs)

# 定義一個模型接收encoder_input_data` & `decoder_input_data`做為輸入而輸出`decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# 打印出模型結構
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_input (InputLayer)     [(None, None)]       0           []
#
#  decoder_input (InputLayer)     [(None, None)]       0           []
#
#  enc_embedding (Embedding)      (None, None, 128)    9472        ['encoder_input[0][0]']
#
#  dec_embedding (Embedding)      (None, None, 64)     155904      ['decoder_input[0][0]']
#
#  encoder_lstm (LSTM)            [(None, None, 256),  394240      ['enc_embedding[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  decoder_lstm (LSTM)            [(None, None, 256),  328704      ['dec_embedding[0][0]',
#                                  (None, 256),                     'encoder_lstm[0][1]',
#                                  (None, 256)]                     'encoder_lstm[0][2]']
#
#  dot (Dot)                      (None, None, None)   0           ['decoder_lstm[0][0]',
#                                                                   'encoder_lstm[0][0]']
#
#  activation (Activation)        (None, None, None)   0           ['dot[0][0]']
#
#  dot_1 (Dot)                    (None, None, 256)    0           ['activation[0][0]',
#                                                                   'encoder_lstm[0][0]']
#
#  concatenate (Concatenate)      (None, None, 512)    0           ['dot_1[0][0]',
#                                                                   'decoder_lstm[0][0]']
#
#  concat_output (Dense)          (None, None, 2435)   1249155     ['concatenate[0][0]']
#
#  second_output (Dense)          (None, None, 2435)   5931660     ['concat_output[0][0]']
#
#  decoder_output (Dense)         (None, None, 2435)   5931660     ['second_output[0][0]']
#
# ==================================================================================================
# Total params: 14,000,795
# Trainable params: 14,000,795
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### STEP 5.訓練模型

# %%
checkpoint = keras.callbacks.ModelCheckpoint('./s2s.h5', monitor='val_loss', mode="min", save_best_only=True, verbose=1)
# earlystopping = keras.callbacks.EarlyStopping(monitor='val_loss', mode="min", patience=5, verbose=1)
# rlr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, verbose=1, mode='auto', min_delta=0.0001)

# 設定模型超參數
model.compile(optimizer='rmsprop', loss='categorical_crossentropy')

# 開始訓練
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=250,
          validation_split=0.2,
          callbacks=[checkpoint])
# Out:
# Epoch 1/250
# 188/188 [==============================] - ETA: 0s - loss: 1.9610
# Epoch 1: val_loss improved from inf to 2.26408, saving model to ./s2s.h5
# 188/188 [==============================] - 17s 61ms/step - loss: 1.9610 - val_loss: 2.2641
# Epoch 2/250
# 188/188 [==============================] - ETA: 0s - loss: 1.5741
# Epoch 2: val_loss improved from 2.26408 to 2.05721, saving model to ./s2s.h5
# 188/188 [==============================] - 11s 59ms/step - loss: 1.5741 - val_loss: 2.0572
# Epoch 3/250
# 187/188 [============================>.] - ETA: 0s - loss: 1.4052
# Epoch 3: val_loss improved from 2.05721 to 1.91355, saving model to ./s2s.h5
# 188/188 [==============================] - 10s 53ms/step - loss: 1.4051 - val_loss: 1.9135
# Epoch 4/250
# 187/188 [============================>.] - ETA: 0s - loss: 1.2871
# Epoch 4: val_loss improved from 1.91355 to 1.84758, saving model to ./s2s.h5
# 188/188 [==============================] - 10s 53ms/step - loss: 1.2870 - val_loss: 1.8476
# Epoch 5/250
# 187/188 [============================>.] - ETA: 0s - loss: 1.2128
# Epoch 5: val_loss improved from 1.84758 to 1.81951, saving model to ./s2s.h5
# 188/188 [==============================] - 10s 53ms/step - loss: 1.2131 - val_loss: 1.8195
# Epoch 6/250
# 188/188 [==============================] - ETA: 0s - loss: 1.1539
# Epoch 6: val_loss improved from 1.81951 to 1.73953, saving model to ./s2s.h5
# 188/188 [==============================] - 10s 53ms/step - loss: 1.1539 - val_loss: 1.7395
# Epoch 7/250
# 188/188 [==============================] - ETA: 0s - loss: 1.0913
# Epoch 7: val_loss improved from 1.73953 to 1.71456, saving model to ./s2s.h5
# 188/188 [==============================] - 10s 53ms/step - loss: 1.0913 - val_loss: 1.7146
# Epoch 8/250
# 187/188 [============================>.] - ETA: 0s - loss: 1.0392
# Epoch 8: val_loss improved from 1.71456 to 1.67977, saving model to ./s2s.h5
# 188/188 [==============================] - 10s 53ms/step - loss: 1.0390 - val_loss: 1.6798
# Epoch 9/250
# 188/188 [==============================] - ETA: 0s - loss: 0.9793
# Epoch 9: val_loss improved from 1.67977 to 1.65874, saving model to ./s2s.h5
# 188/188 [==============================] - 10s 53ms/step - loss: 0.9793 - val_loss: 1.6587
# Epoch 10/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.9237
# Epoch 10: val_loss improved from 1.65874 to 1.61260, saving model to ./s2s.h5
# 188/188 [==============================] - 11s 56ms/step - loss: 0.9234 - val_loss: 1.6126
# Epoch 11/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.8703
# Epoch 11: val_loss improved from 1.61260 to 1.59058, saving model to ./s2s.h5
# 188/188 [==============================] - 10s 53ms/step - loss: 0.8699 - val_loss: 1.5906
# Epoch 12/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.8206
# Epoch 12: val_loss improved from 1.59058 to 1.56340, saving model to ./s2s.h5
# 188/188 [==============================] - 10s 53ms/step - loss: 0.8205 - val_loss: 1.5634
# Epoch 13/250
# 188/188 [==============================] - ETA: 0s - loss: 0.7727
# Epoch 13: val_loss improved from 1.56340 to 1.55229, saving model to ./s2s.h5
# 188/188 [==============================] - 10s 53ms/step - loss: 0.7727 - val_loss: 1.5523
# Epoch 14/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.7294
# Epoch 14: val_loss improved from 1.55229 to 1.55007, saving model to ./s2s.h5
# 188/188 [==============================] - 10s 53ms/step - loss: 0.7298 - val_loss: 1.5501
# Epoch 15/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.6856
# Epoch 15: val_loss improved from 1.55007 to 1.51318, saving model to ./s2s.h5
# 188/188 [==============================] - 10s 53ms/step - loss: 0.6856 - val_loss: 1.5132
# Epoch 16/250
# 188/188 [==============================] - ETA: 0s - loss: 0.6427
# Epoch 16: val_loss improved from 1.51318 to 1.50357, saving model to ./s2s.h5
# 188/188 [==============================] - 10s 53ms/step - loss: 0.6427 - val_loss: 1.5036
# Epoch 17/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.6040
# Epoch 17: val_loss did not improve from 1.50357
# 188/188 [==============================] - 10s 52ms/step - loss: 0.6040 - val_loss: 1.5066
# Epoch 18/250
# 188/188 [==============================] - ETA: 0s - loss: 0.5679
# Epoch 18: val_loss improved from 1.50357 to 1.48711, saving model to ./s2s.h5
# 188/188 [==============================] - 10s 53ms/step - loss: 0.5679 - val_loss: 1.4871
# Epoch 19/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.5355
# Epoch 19: val_loss improved from 1.48711 to 1.47015, saving model to ./s2s.h5
# 188/188 [==============================] - 10s 53ms/step - loss: 0.5355 - val_loss: 1.4701
# Epoch 20/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.5026
# Epoch 20: val_loss did not improve from 1.47015
# 188/188 [==============================] - 10s 51ms/step - loss: 0.5027 - val_loss: 1.4747
# Epoch 21/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.4709
# Epoch 21: val_loss improved from 1.47015 to 1.46463, saving model to ./s2s.h5
# 188/188 [==============================] - 10s 53ms/step - loss: 0.4710 - val_loss: 1.4646
# Epoch 22/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.4422
# Epoch 22: val_loss improved from 1.46463 to 1.45316, saving model to ./s2s.h5
# 188/188 [==============================] - 10s 53ms/step - loss: 0.4423 - val_loss: 1.4532
# Epoch 23/250
# 188/188 [==============================] - ETA: 0s - loss: 0.4126
# Epoch 23: val_loss did not improve from 1.45316
# 188/188 [==============================] - 10s 51ms/step - loss: 0.4126 - val_loss: 1.4859
# Epoch 24/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.3881
# Epoch 24: val_loss did not improve from 1.45316
# 188/188 [==============================] - 10s 51ms/step - loss: 0.3881 - val_loss: 1.4640
# Epoch 25/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.3633
# Epoch 25: val_loss did not improve from 1.45316
# 188/188 [==============================] - 10s 55ms/step - loss: 0.3632 - val_loss: 1.4607
# Epoch 26/250
# 188/188 [==============================] - ETA: 0s - loss: 0.3415
# Epoch 26: val_loss did not improve from 1.45316
# 188/188 [==============================] - 10s 52ms/step - loss: 0.3415 - val_loss: 1.4572
# Epoch 27/250
# 188/188 [==============================] - ETA: 0s - loss: 0.3172
# Epoch 27: val_loss improved from 1.45316 to 1.45172, saving model to ./s2s.h5
# 188/188 [==============================] - 10s 53ms/step - loss: 0.3172 - val_loss: 1.4517
# Epoch 28/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.2971
# Epoch 28: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2973 - val_loss: 1.4709
# Epoch 29/250
# 188/188 [==============================] - ETA: 0s - loss: 0.2796
# Epoch 29: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 51ms/step - loss: 0.2796 - val_loss: 1.4645
# Epoch 30/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.2599
# Epoch 30: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0
val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0236 - val_loss: 1.6022
# Epoch 68/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0229
# Epoch 68: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0230 - val_loss: 1.6170
# Epoch 69/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0226
# Epoch 69: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 55ms/step - loss: 0.0226 - val_loss: 1.6212
# Epoch 70/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0211
# Epoch 70: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0211 - val_loss: 1.6091
# Epoch 71/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0209
# Epoch 71: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0209 - val_loss: 1.6157
# Epoch 72/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0199
# Epoch 72: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0199 - val_loss: 1.6132
# Epoch 73/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0193
# Epoch 73: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0193 - val_loss: 1.6255
# Epoch 74/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0187
# Epoch 74: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0187 - val_loss: 1.6309
# Epoch 75/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0183
# Epoch 75: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0183 - val_loss: 1.6260
# Epoch 76/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0177
# Epoch 76: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0177 - val_loss: 1.6256
# Epoch 77/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0179
# Epoch 77: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0179 - val_loss: 1.6371
# Epoch 78/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0167
# Epoch 78: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0167 - val_loss: 1.6265
# Epoch 79/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0165
# Epoch 79: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0165 - val_loss: 1.6133
# Epoch 80/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0153
# Epoch 80: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0153 - val_loss: 1.6275
# Epoch 81/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0155
# Epoch 81: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0155 - val_loss: 1.6317
# Epoch 82/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0154
# Epoch 82: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0154 - val_loss: 1.6366
# Epoch 83/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0152
# Epoch 83: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 54ms/step - loss: 0.0152 - val_loss: 1.6383
# Epoch 84/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0148
# Epoch 84: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 54ms/step - loss: 0.0148 - val_loss: 1.6434
# Epoch 85/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0144
# Epoch 85: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0144 - val_loss: 1.6317
# Epoch 86/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0145
# Epoch 86: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0145 - val_loss: 1.6280
# Epoch 87/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0144
# Epoch 87: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0144 - val_loss: 1.6410
# Epoch 88/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0140
# Epoch 88: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0140 - val_loss: 1.6657
# Epoch 89/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0136
# Epoch 89: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0136 - val_loss: 1.6505
# Epoch 90/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0134
# Epoch 90: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0134 - val_loss: 1.6445
# Epoch 91/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0120
# Epoch 91: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0120 - val_loss: 1.6447
# Epoch 92/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0126
# Epoch 92: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0126 - val_loss: 1.6509
# Epoch 93/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0125
# Epoch 93: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0125 - val_loss: 1.6497
# Epoch 94/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0127
# Epoch 94: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0126 - val_loss: 1.6371
# Epoch 95/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0123
# Epoch 95: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0123 - val_loss: 1.6478
# Epoch 96/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0123
# Epoch 96: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0123 - val_loss: 1.6585
# Epoch 97/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0119
# Epoch 97: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0119 - val_loss: 1.6529
# Epoch 98/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0123
# Epoch 98: val_loss did not improve from 1.45172
# 188/188 [==============================] - 11s 56ms/step - loss: 0.0123 - val_loss: 1.6548
# Epoch 99/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0118
# Epoch 99: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0118 - val_loss: 1.6610
# Epoch 100/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0120
# Epoch 100: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0120 - val_loss: 1.6675
# Epoch 101/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0119
# Epoch 101: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0119 - val_loss: 1.6603
# Epoch 102/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0120
# Epoch 102: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0120 - val_loss: 1.6694
# Epoch 103/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0117
# Epoch 103: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0117 - val_loss: 1.6667
# Epoch 104/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0116
# Epoch 104: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0116 - val_loss: 1.6594
# Epoch 105/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0116
# Epoch 105: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0116 - val_loss: 1.6722
# Epoch 106/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0114
# Epoch 106: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0114 - val_loss: 1.6647
# Epoch 107/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0114
# Epoch 107: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0114 - val_loss: 1.6644
# Epoch 108/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0110
# Epoch 108: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0110 - val_loss: 1.6649
# Epoch 109/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 109: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0108 - val_loss: 1.6620
# Epoch 110/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 110: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0108 - val_loss: 1.6761
# Epoch 111/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0106
# Epoch 111: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0106 - val_loss: 1.6848
# Epoch 112/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0104
# Epoch 112: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 54ms/step - loss: 0.0104 - val_loss: 1.6842
# Epoch 113/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0104
# Epoch 113: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 55ms/step - loss: 0.0104 - val_loss: 1.6753
# Epoch 114/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0100
# Epoch 114: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0100 - val_loss: 1.6792
# Epoch 115/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0102
# Epoch 115: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0102 - val_loss: 1.6820
# Epoch 116/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0100
# Epoch 116: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0100 - val_loss: 1.6856
# Epoch 117/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0103
# Epoch 117: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0103 - val_loss: 1.6860
# Epoch 118/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0100
# Epoch 118: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0100 - val_loss: 1.6848
# Epoch 119/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0103
# Epoch 119: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0103 - val_loss: 1.6737
# Epoch 120/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0099
# Epoch 120: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 52ms/step - loss: 0.0099 - val_loss: 1.6667
# Epoch 121/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0097
# Epoch 121: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0097 - val_loss: 1.6898
# Epoch 122/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0097
# Epoch 122: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0097 - val_loss: 1.6799
# Epoch 123/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0094
# Epoch 123: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0094 - val_loss: 1.6851
# Epoch 124/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0094
# Epoch 124: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0094 - val_loss: 1.6891
# Epoch 125/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0094
# Epoch 125: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0094 - val_loss: 1.6966
# Epoch 126/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0094
# Epoch 126: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0094 - val_loss: 1.6928
# Epoch 127/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0095
# Epoch 127: val_loss did not improve from 1.45172
# 188/188 [==============================] - 11s 56ms/step - loss: 0.0095 - val_loss: 1.6940
# Epoch 128/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0090
# Epoch 128: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0090 - val_loss: 1.6948
# Epoch 129/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0091
# Epoch 129: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0091 - val_loss: 1.7086
# Epoch 130/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0093
# Epoch 130: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0093 - val_loss: 1.7033
# Epoch 131/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0093
# Epoch 131: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 54ms/step - loss: 0.0094 - val_loss: 1.7039
# Epoch 132/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0095
# Epoch 132: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 55ms/step - loss: 0.0095 - val_loss: 1.6958
# Epoch 133/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0090
# Epoch 133: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 54ms/step - loss: 0.0090 - val_loss: 1.7033
# Epoch 134/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0093
# Epoch 134: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0093 - val_loss: 1.6968
# Epoch 135/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0096
# Epoch 135: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0096 - val_loss: 1.7022
# Epoch 136/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 136: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0092 - val_loss: 1.7048
# Epoch 137/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0088
# Epoch 137: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0088 - val_loss: 1.7117
# Epoch 138/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 138: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0091 - val_loss: 1.7173
# Epoch 139/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 139: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0091 - val_loss: 1.7280
# Epoch 140/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0089
# Epoch 140: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0089 - val_loss: 1.6971
# Epoch 141/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0088
# Epoch 141: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 55ms/step - loss: 0.0088 - val_loss: 1.7032
# Epoch 142/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 142: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 55ms/step - loss: 0.0086 - val_loss: 1.7001
# Epoch 143/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 143: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0086 - val_loss: 1.7138
# Epoch 144/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0083
# Epoch 144: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0083 - val_loss: 1.7179
# Epoch 145/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0088
# Epoch 145: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0088 - val_loss: 1.7178
# Epoch 146/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0089
# Epoch 146: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 54ms/step - loss: 0.0089 - val_loss: 1.7164
# Epoch 147/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0088
# Epoch 147: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0088 - val_loss: 1.7178
# Epoch 148/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0088
# Epoch 148: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 54ms/step - loss: 0.0088 - val_loss: 1.7260
# Epoch 149/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0087
# Epoch 149: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 53ms/step - loss: 0.0087 - val_loss: 1.7125
# Epoch 150/250
# 188/188 [==============================] - ETA: 0s - loss: 0.0083
# Epoch 150: val_loss did not improve from 1.45172
# 188/188 [==============================] - 10s 54ms/step - loss: 0.0083 - val_loss: 1.7264
# Epoch 151/250
# 188/188 [==============================] - ETA: 0s - loss: 0.
val_loss did not improve from 1.45172
# 188/188 [==============================] - 11s 58ms/step - loss: 0.0065 - val_loss: 1.8139
# Epoch 250/250
# 187/188 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 250: val_loss did not improve from 1.45172
# 188/188 [==============================] - 11s 57ms/step - loss: 0.0067 - val_loss: 1.8096

# %% [markdown]
# ### STEP 6.模型預測
#
# ![seq2seq_predict](https://4.bp.blogspot.com/-6DALk3-hPtA/WO04i5GgXLI/AAAAAAAABtc/2t9mYz4nQDg9jLoHdTkywDUfxIOFJfC_gCLcB/s640/Seq2SeqDiagram.gif)

# %% [markdown]
# seq2seq+atention

# %%
# 定義要進行取樣的模型

# 定義編碼器(encoder)的模型
encoder_model = Model(encoder_inputs, encoder_outputs_3) # encoder_outputs is needed for attention

# 定義解碼器LSTM cell的初始權重輸入
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
encoder_outputs_holder = Input(shape=(None, latent_dim))

decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
encoder_outputs_3holder = [encoder_outputs_holder, decoder_state_input_h, decoder_state_input_c]

# 解碼器(decoder)定義初始狀態(initial decoder state)
decoder_outputs, state_h, state_c = decoder_lstm(
    dec_embed(decoder_inputs), initial_state=decoder_states_inputs) #我們使用`decoder_states_inputs`來做為初始值(initial state)
decoder_states = [state_h, state_c] # train 沒用到, inference 會用到

attention = dot([decoder_outputs, encoder_outputs_holder], axes=[2, 2])
attention = Activation('softmax')(attention)
context = dot([attention, encoder_outputs_holder], axes=[2,1])
decoder_outputs = concatenate([context, decoder_outputs])
decoder_outputs = concat_dense(decoder_outputs)
decoder_outputs = second_dense(decoder_outputs)
decoder_outputs = decoder_dense(decoder_outputs)

# 定義解碼器(decoder)的模型
decoder_model = Model(
    [decoder_inputs] + encoder_outputs_3holder,
    [decoder_outputs] +  decoder_states)


# 反向查找字符索引來將序列解碼為可讀的內容。
# reverse_input_char_index = dict(
#     (i, char) for char, i in input_token_index.items())

reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())

# 對序列進行解碼
def decode_sequence(input_seq):
    # 將輸入編碼成為state向量
    encoder_outputs = encoder_model.predict(input_seq)
    # 產生長度為1的空白目標序列
    target_seq = np.zeros((1, 1))

    # 發佈特定的目標序列起始字符"[SOS]",在這個範例中是使用 "\t"字符
    target_seq[0, 0] = target_token_index['\t'] # decoder_input_data

    # 對批次的序列進行抽樣迴圈
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + encoder_outputs)

        # 對符標抽樣
        sampled_token_index = np.argmax(output_tokens[0, -1, :]) # decoder_output_data
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # 停止迴圈的條件: 到達最大的長度或是找到"停止[EOS]"字符,在這個範例中是使用 "\n"字符
        if (sampled_char == '\n' or
           len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # 更新目標序列(of length 1).
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        # 更新 states
        encoder_outputs = [encoder_outputs[0], h, c] # update h & c

    return decoded_sentence


for seq_index in range(100):
    # 從訓練集中取出一個序列並試著解碼
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_texts[seq_index])
    print('Decoded sentence:', decoded_sentence)
# Out:
# -
# Input sentence: Hi.
# Decoded sentence: 你好。
#
# -
# Input sentence: Hi.
# Decoded sentence: 你好。
#
# -
# Input sentence: Run.
# Decoded sentence: 你用跑的。
#
# -
# Input sentence: Wait!
# Decoded sentence: 等等！
#
# -
# Input sentence: Hello!
# Decoded sentence: 你好。
#
# -
# Input sentence: I try.
# Decoded sentence: 讓我來。
#
# -
# Input sentence: I won!
# Decoded sentence: 我贏了。
#
# -
# Input sentence: Oh no!
# Decoded sentence: 不會吧。
#
# -
# Input sentence: Cheers!
# Decoded sentence: 乾杯!
#
# -
# Input sentence: He ran.
# Decoded sentence: 他跑了。
#
# -
# Input sentence: Hop in.
# Decoded sentence: 跳進來。
#
# -
# Input sentence: I lost.
# Decoded sentence: 我迷失了。
#
# -
# Input sentence: I quit.
# Decoded sentence: 我退出。
#
# -
# Input sentence: I'm OK.
# Decoded sentence: 我沒事。
#
# -
# Input sentence: Listen.
# Decoded sentence: 聽著。
#
# -
# Input sentence: No way!
# Decoded sentence: 沒門！
#
# -
# Input sentence: No way!
# Decoded sentence: 沒門！
#
# -
# Input sentence: Really?
# Decoded sentence: 你確定？
#
# -
# Input sentence: Try it.
# Decoded sentence: 試試吧。
#
# -
# Input sentence: We try.
# Decoded sentence: 我們來試試。
#
# -
# Input sentence: Why me?
# Decoded sentence: 為什麼是我？
#
# -
# Input sentence: Ask Tom.
# Decoded sentence: 去問湯姆。
#
# -
# Input sentence: Be calm.
# Decoded sentence: 冷靜點。
#
# -
# Input sentence: Be fair.
# Decoded sentence: 公平點。
#
# -
# Input sentence: Be kind.
# Decoded sentence: 友善點。
#
# -
# Input sentence: Be nice.
# Decoded sentence: 和氣點。
#
# -
# Input sentence: Call me.
# Decoded sentence: 聯繫我。
#
# -
# Input sentence: Call us.
# Decoded sentence: 聯繫我們。
#
# -
# Input sentence: Come in.
# Decoded sentence: 進來。
#
# -
# Input sentence: Get Tom.
# Decoded sentence: 找到湯姆。
#
# -
# Input sentence: Get out!
# Decoded sentence: 滾出去！
#
# -
# Input sentence: Go away!
# Decoded sentence: 走開！
#
# -
# Input sentence: Go away!
# Decoded sentence: 走開！
#
# -
# Input sentence: Go away.
# Decoded sentence: 走開！
#
# -
# Input sentence: Goodbye!
# Decoded sentence: 告辭！
#
# -
# Input sentence: Goodbye!
# Decoded sentence: 告辭！
#
# -
# Input sentence: Hang on!
# Decoded sentence: 等一下！
#
# -
# Input sentence: He came.
# Decoded sentence: 他來了。
#
# -
# Input sentence: He runs.
# Decoded sentence: 他跑。
#
# -
# Input sentence: Help me.
# Decoded sentence: 幫我一下。
#
# -
# Input sentence: Hold on.
# Decoded sentence: 堅持。
#
# -
# Input sentence: Hug Tom.
# Decoded sentence: 抱抱湯姆！
#
# -
# Input sentence: I agree.
# Decoded sentence: 我同意。
#
# -
# Input sentence: I'm ill.
# Decoded sentence: 我生病了。
#
# -
# Input sentence: I'm old.
# Decoded sentence: 我老了。
#
# -
# Input sentence: It's OK.
# Decoded sentence: 沒關係。
#
# -
# Input sentence: It's me.
# Decoded sentence: 是我。
#
# -
# Input sentence: Join us.
# Decoded sentence: 來加入我們吧。
#
# -
# Input sentence: Keep it.
# Decoded sentence: 留著吧。
#
# -
# Input sentence: Kiss me.
# Decoded sentence: 吻我。
#
# -
# Input sentence: Perfect!
# Decoded sentence: 完美！
#
# -
# Input sentence: See you.
# Decoded sentence: 再見！
#
# -
# Input sentence: Shut up!
# Decoded sentence: 閉嘴！
#
# -
# Input sentence: Skip it.
# Decoded sentence: 不管它。
#
# -
# Input sentence: Take it.
# Decoded sentence: 拿走吧。
#
# -
# Input sentence: Wake up!
# Decoded sentence: 醒醒！
#
# -
# Input sentence: Wash up.
# Decoded sentence: 去清洗一下。
#
# -
# Input sentence: We know.
# Decoded sentence: 我們知道。
#
# -
# Input sentence: Welcome.
# Decoded sentence: 歡迎。
#
# -
# Input sentence: Who won?
# Decoded sentence: 誰贏了？
#
# -
# Input sentence: Why not?
# Decoded sentence: 為什麼不？
#
# -
# Input sentence: You run.
# Decoded sentence: 你跑。
#
# -
# Input sentence: Back off.
# Decoded sentence: 往後退點。
#
# -
# Input sentence: Be still.
# Decoded sentence: 靜靜的，別動。
#
# -
# Input sentence: Cuff him.
# Decoded sentence: 把他銬上。
#
# -
# Input sentence: Drive on.
# Decoded sentence: 往前開。
#
# -
# Input sentence: Get away!
# Decoded sentence: 走開！
#
# -
# Input sentence: Get away!
# Decoded sentence: 走開！
#
# -
# Input sentence: Get down!
# Decoded sentence: 趴下！
#
# -
# Input sentence: Get lost!
# Decoded sentence: 滾！
#
# -
# Input sentence: Get real.
# Decoded sentence: 醒醒吧。
#
# -
# Input sentence: Grab Tom.
# Decoded sentence: 抓住湯姆。
#
# -
# Input sentence: Grab him.
# Decoded sentence: 抓住他。
#
# -
# Input sentence: Have fun.
# Decoded sentence: 玩得開心。
#
# -
# Input sentence: He tries.
# Decoded sentence: 他來試試。
#
# -
# Input sentence: Humor me.
# Decoded sentence: 你就隨了我的意吧。
#
# -
# Input sentence: Hurry up.
# Decoded sentence: 趕快!
#
# -
# Input sentence: Hurry up.
# Decoded sentence: 趕快!
#
# -
# Input sentence: I forgot.
# Decoded sentence: 我忘了。
#
# -
# Input sentence: I resign.
# Decoded sentence: 我放棄。
#
# -
# Input sentence: I'll pay.
# Decoded sentence: 我來付錢。
#
# -
# Input sentence: I'm busy.
# Decoded sentence: 我很忙。
#
# -
# Input sentence: I'm cold.
# Decoded sentence: 我冷。
#
# -
# Input sentence: I'm fine.
# Decoded sentence: 我很好。
#
# -
# Input sentence: I'm full.
# Decoded sentence: 我吃飽了。
#
# -
# Input sentence: I'm sick.
# Decoded sentence: 我病了。
#
# -
# Input sentence: I'm sick.
# Decoded sentence: 我病了。
#
# -
# Input sentence: Leave me.
# Decoded sentence: 讓我一個人呆會兒。
#
# -
# Input sentence: Let's go!
# Decoded sentence: 我們走吧!
#
# -
# Input sentence: Let's go!
# Decoded sentence: 我們走吧!
#
# -
# Input sentence: Let's go!
# Decoded sentence: 我們走吧!
#
# -
# Input sentence: Look out!
# Decoded sentence: 當心！
#
# -
# Input sentence: She runs.
# Decoded sentence: 她跑。
#
# -
# Input sentence: Stand up.
# Decoded sentence: 起立。
#
# -
# Input sentence: They won.
# Decoded sentence: 他們贏了。
#
# -
# Input sentence: Tom died.
# Decoded sentence: 湯姆去世了。
#
# -
# Input sentence: Tom quit.
# Decoded sentence: 湯姆不干了。
#
# -
# Input sentence: Tom swam.
# Decoded sentence: 湯姆游泳了。
#
# -
# Input sentence: Trust me.
# Decoded sentence: 相信我。
#
# -
# Input sentence: Try hard.
# Decoded sentence: 努力。
